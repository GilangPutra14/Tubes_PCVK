# %% [markdown]
# TUGAS KELOMPOK PCVK
#
# MENDETEKSI TUMOR PADA OTAK DENGAN BEBERAPA METODE PEMBELAJARAN
#
# Disusun Oleh :
# 1. Arlan Ady Pratama
# 2. Gilang Permana Putra
# 3. Muhammad Hajar Priatmaja

# %%
#Akses Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage import io
from skimage.color import rgb2hsv

rgb_img = io.imread('/content/drive/MyDrive/Brain Tumor/Brain Tumor/Y253.JPG')



hsv_hsv = rgb2hsv(rgb_img)
hue_img = hsv_hsv[:,:, 2]

fig, ([ax0, ax1]) = plt.subplots(1,2, figsize=(20, 20))

ax0.imshow(hue_img)
ax0.set_title("Original")
ax1.imshow(hsv_hsv)
ax1.set_title("Grayscale")

plt.show()

# %%
from skimage import data, filters, io
import matplotlib.pyplot as plt
import cv2

img = io.imread('/content/drive/MyDrive/Brain Tumor/Brain Tumor/Y253.JPG')

img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imgC = cv2.Canny(img,20,40)

imgR = filters.roberts(img)
imgP = filters.prewitt(img)
flg, ax = plt.subplots(1,3, figsize=(10,8))
ax[0].imshow(img, cmap='gray')
ax[1].imshow(imgC, cmap='gray')
ax[2].imshow(imgP, cmap='gray')

ax[0].set_title("Original")
ax[1].set_title("Canny")
ax[2].set_title("Prewitt")

plt.show()

# %%
import cv2
import numpy as np
from skimage import io

image = io.imread('/content/drive/MyDrive/Brain Tumor/Brain Tumor/Y253.JPG')
gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
io.imshow(image)

ret, thresh = cv2.threshold(gray,80,255,80)
contours, hierarchy = cv2.findContours(thresh.copy(), cv2.RETR_LIST,cv2.CHAIN_APPROX_NONE)
n = len(contours)-1
contours = sorted(contours, key = cv2.contourArea, reverse = False)[:n]
for c in contours:
  hull = cv2.convexHull(c)
cv2.drawContours(image,[hull],0,(0,255,0),2)
io.imshow(image)
io.show()

# %%
import cv2 as cv
import numpy as np
from matplotlib import pyplot as plt

img = cv.imread ('/content/drive/MyDrive/Brain Tumor/Brain Tumor/Y253.JPG')

img_gray = cv.cvtColor(img, cv2.COLOR_BGR2GRAY) 
plt.imshow(img_gray, cmap='gray')
plt.show()

# %%
ret, img_binary = cv2.threshold(img,200,255, cv2.THRESH_BINARY)
plt.imshow(img_binary)
plt.show()
